# %%
import os
import glob

# %%
for root, _dir, files in os.walk("."):
    for file in files:
        if file.endswith(".geojson"):
            os.rename(root + '\\' + file, root + '\\' + file.lower())

# %%
glob.glob("*/*")
# Out:
# ['ac\\ac-shape.geojson',
#  'ac\\ac.geojson',
#  'ac\\drawMap.js',
#  'ac\\dropdownMenu.js',
#  'ac\\index.html',
#  'ac\\style.css',
#  'al\\al-shape.geojson',
#  'al\\al.geojson',
#  'al\\drawMap.js',
#  'al\\dropdownMenu.js',
#  'al\\index.html',
#  'al\\style.css',
#  'am\\am-shape.geojson',
#  'am\\am.geojson',
#  'am\\drawMap.js',
#  'am\\dropdownMenu.js',
#  'am\\index.html',
#  'am\\style.css',
#  'ap\\ap-shape.geojson',
#  'ap\\ap.geojson',
#  'ap\\drawMap.js',
#  'ap\\dropdownMenu.js',
#  'ap\\index.html',
#  'ap\\style.css',
#  'ba\\ba-shape.geojson',
#  'ba\\ba.geojson',
#  'ba\\drawMap.js',
#  'ba\\dropdownMenu.js',
#  'ba\\index.html',
#  'ba\\style.css',
#  'ce\\ce-shape.geojson',
#  'ce\\ce.geojson',
#  'ce\\drawMap.js',
#  'ce\\dropdownMenu.js',
#  'ce\\index.html',
#  'ce\\style.css',
#  'completo\\drawMap.js',
#  'completo\\dropdownMenu.js',
#  'completo\\map.html',
#  'completo\\states-shapes.geojson',
#  'completo\\streets.geojson',
#  'completo\\style.css',
# ...
